# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
def plot_image(path):
    img = Image.open(path)
    
    plt.figure(figsize=(8, 6))
    plt.axis('off')
    plt.imshow(img)

# %%
## Images to look at

image1 = 'demo/photo1.jpg'
image2 = 'demo/photo2.jpg'
image3 = 'demo/photo3.jpg'
image4 = 'demo/photo4.jpg'
image5 = 'demo/photo5.jpg'

# %% [markdown]
# # How to make predictions
#
# - just run the predict.py file and pass some arguments like:
#     - model_name: model to use
#     - image_path: path of the image
#     - num_captions: number of captions per image

# %% [markdown]
# # Image 1

# %%
plot_image(image1)
# !python predict.py --image_path=$image1 --num_captions=4
# Out:
# captions:
# 0) a crowd of people standing next to each other.
# 1) a group of people that are standing in the street.
# 2) a crowd of people walking down a street.
# 3) a group of people standing around each other in a room.

# %% [markdown]
# # Image 2

# %%
plot_image(image2)
# !python predict.py --image_path=$image2 --num_captions=4
# Out:
# captions:
# 0) a woman sitting in front of a laptop computer.
# 1) a woman holding a cell phone to her ear.
# 2) a woman holding up a smart phone in front of her face.
# 3) a woman holding a cell phone up to her ear.

# %% [markdown]
# # Image 3

# %%
plot_image(image3)
# !python predict.py --image_path=$image3 --num_captions=4
# Out:
# captions:
# 0) a group of people sitting around a table.
# 1) a group of people sitting at tables with laptops.
# 2) a group of people sitting around a table with laptops.
# 3) a group of people sitting at a table with laptops.

# %% [markdown]
# # Image 4

# %%
plot_image(image4)
# !python predict.py --image_path=$image4 --num_captions=4
# Out:
# captions:
# 0) a couple of boats parked next to each other on a beach.
# 1) a parking lot filled with parked cars next to a building.
# 2) a parking lot filled with lots of buses and cars.
# 3) a couple of boats parked next to each other.

# %% [markdown]
# ## Poor dorms were confused with boats

# %% [markdown]
# # Image 5

# %%
plot_image(image5)
# !python predict.py --image_path=$image5 --num_captions=4
# Out:
# captions:
# 0) a group of people standing next to each other.
# 1) a group of people that are standing around a table.
# 2) a couple of people that are standing in the street.
# 3) a group of people standing next to each other holding wine glasses.
